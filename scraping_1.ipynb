# %%
from dputils.scrape import Scraper,Tag

# %%
sc = Scraper("https://timesofindia.indiatimes.com/india")

# %%
print(sc.soup) #soup to see full page
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
# <html class="mweb"><head><meta content="The Times of India" property="og:site_name"/><meta content="website" property="og:type"/><meta content="556964827" property="fb:admins"/><meta content="117787264903013" property="fb:app_id"/><meta content="26781952138" property="fb:pages"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="ZgFICIedNvVZl5pV9EfAUeenwta9vBY0Za_GgmV4zuw" name="google-site-verification"/><meta content="b1abb36a8d5c19c9" name="y_key"/><meta name="twitter:card" value="summary_large_image"/><meta name="twitter:site" value="@timesofindia"/><meta content="Monday, 03 April, 2023 03:15:49PM;
# ...

# %%
sc.soup.title
# Out:
# <title>India News | Latest News Headlines &amp; Live Updates from India - Times of India</title>

# %%
sc.soup.find_all('a')
# Out:
# [<a class="view-all-btn" href="https://www.timespoints.com/products?utm_source=TOI&amp;utm_medium=timespoint&amp;utm_campaign=daily_checkin" rel="noopener nofollow noreferrer" target="_blank">VIEW ALL</a>,
#  <a class="redeem-btn tp-redeem" href="javascript: void(0)">redeem</a>,
#  <a class="tp-btn tp-redeem" href="javascript: void(0)">REDEEM POINTS</a>,
#  <a class="tp-btn" href="javascript:void(0)">KNOW MORE</a>,
#  <a href="https://jsso.indiatimes.com/sso/identity/profile/edit?channel=toi" pg="#Click-Edit_Profile-1~Header-User_Profile" target="_blank">Edit Profile</a>,
#  <a href="https://www.timespoints.com/#/products?utm_source=TOI&amp;utm_medium=Header_Dropdown&amp;utm_campaign=TOI_HeaderDropdown" pg="#Click-TP_Redeem-3~Header-User_Profile" rel="nofollow" target="_blank">Redeem</a>,
# ...
