# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
sns.histplot(tips, x="sex",y='total_bill',bins=15,kde=True)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.set_palette('rainbow')
sns.barplot(tips,x="total_bill",y="sex",hue='time')
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
tips.columns.tolist()
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
sns.set_palette('rainbow')

# %%
sns.set_palette('pastel')
sns.relplot(tips,x='total_bill',y='smoker',hue='sex')

# %%
sns.histplot(tips,x='total_bill',y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=tips,x="total_bill", y="tip",hue="size", palette="ch:r=-.5,l=.75")

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip",
    size="size", sizes=(15, 200)
)

# %%
sns.load_dataset("dowjones")
sns.relplot(dowjones, x="Date", y="Price", kind="line")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 sns.load_dataset("dowjones")
# ----> 2 sns.relplot(dowjones, x="Date", y="Price", kind="line")
#
# NameError: name 'dowjones' is not defined

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")

# %%
sns.relplot(fmri, kind="line",x="timepoint", y="signal", errorbar="sd",)

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")

# %%
sns.displot(penguins, x="flipper_length_mm", binwidth=3)

# %%
tips = sns.load_dataset("tips")
sns.displot(tips, x="size")

# %%
sns.displot(tips, x="size", bins=[1, 2, 3, 4, 5, 6, 7])

# %%
sns.displot(tips, x="day", shrink=.8)

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="sex", multiple="dodge")

# %%
tips = sns.load_dataset("tips")
sns.regplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="total_bill", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips);

# %%
sns.lmplot(x="size", y="tip", data=tips, x_jitter=.05);

# %%
anscombe = sns.load_dataset("anscombe")

# %%
sns.lmplot(x="x", y="y", data=anscombe.query("dataset == 'I'"),
           ci=None, scatter_kws={"s": 80});

# %%
tips = sns.load_dataset("tips")
sns.catplot(data=tips, x="day", y="total_bill")

# %%
sns.catplot(data=tips, x="day", y="total_bill", jitter=False)

# %%
sns.catplot(data=tips, x="day", y="total_bill", jitter=False)

# %%
sns.catplot(data=tips, x="day", y="total_bill", kind="swarm")

# %%
sns.catplot(data=tips, x="day", y="total_bill", hue="sex", kind="swarm")

# %%
tips = sns.load_dataset("tips")
g = sns.FacetGrid(tips, col="time")

# %%
g = sns.FacetGrid(tips, col="time")
g.map(sns.histplot, "tip")

# %%
g = sns.FacetGrid(tips, col="day", hue="smoker")
g.map(sns.scatterplot, "total_bill", "tip", alpha=.7)
g.add_legend()

# %%
g = sns.FacetGrid(tips, row="smoker", col="time", margin_titles=True)
g.map(sns.regplot, "size", "total_bill", color=".3", fit_reg=False, x_jitter=.1)
